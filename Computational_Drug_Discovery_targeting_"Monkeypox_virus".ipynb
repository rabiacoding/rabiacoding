# %% [markdown]
# <a href="https://colab.research.google.com/github/rabiacoding/rabiacoding/blob/main/Computational_Drug_Discovery_targeting_%22Monkeypox_virus%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 2.2 MB/s
# ...
#      |████████████████████████████████| 596 kB 8.4 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %%
target = new_client.target
target_query = target.search('Monkeypox virus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    [{'xref_id': 'P05412', 'xref_name': None, 'xre...
# 4    [{'xref_id': 'P05627', 'xref_name': None, 'xre...
# ..                                                 ...
# 164  [{'xref_id': 'P10274', 'xref_name': None, 'xre...
# 165                                                 []
# 166  [{'xref_id': 'Q69422', 'xref_name': None, 'xre...
# 167                                                 []
# 168                                                 []
#
#                                               organism  \
# 0                                      Monkeypox virus
# 1                                         Homo sapiens
# 2                                         Homo sapiens
# 3                                         Homo sapiens
# ...

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL613120'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head()
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None       394374                  []    CHEMBL729931
# 1             None       399398                  []    CHEMBL729931
# 2             None       400857                  []    CHEMBL729931
# 3             None       405209                  []    CHEMBL729931
# 4             None       407658                  []    CHEMBL729931
#
#                                    assay_description assay_type  \
# 0  Inhibitory concentration required against Monk...          F
# 1  Inhibitory concentration required against Monk...          F
# 2  Inhibitory concentration required against Monk...          F
# 3  Inhibitory concentration required against Monk...          F
# 4  Inhibitory concentration required against Monk...          F
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000218
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data1"

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data1"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data1"
# Out:
# total 7
# -rw------- 1 root root 6320 May 24 06:23 bioactivity_data.csv

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ...

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    activity_comment  activity_id activity_properties assay_chembl_id  \
# 0              None       394374                  []    CHEMBL729931
# 1              None       399398                  []    CHEMBL729931
# 2              None       400857                  []    CHEMBL729931
# 3              None       405209                  []    CHEMBL729931
# 4              None       407658                  []    CHEMBL729931
# 5              None       407662                  []    CHEMBL729931
# 6              None      2601917                  []   CHEMBL1034014
# 7              None      2602326                  []   CHEMBL1034014
# 8              None      2602329                  []   CHEMBL1034014
# 9              None     14986431                  []   CHEMBL3387286
# 10             None     14986432                  []   CHEMBL3387286
# 11             None     14986433                  []   CHEMBL3387286
#
#                                     assay_description assay_type  \
# ...

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid
# Out:
# ['CHEMBL112159',
#  'CHEMBL113930',
#  'CHEMBL494759',
#  'CHEMBL114867',
#  'CHEMBL321500',
#  'CHEMBL326139',
#  'CHEMBL1643',
#  'CHEMBL392630',
#  'CHEMBL152',
#  'CHEMBL3290663',
#  'CHEMBL3357216',
#  'CHEMBL3357215']

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL112159                 Nc1ncnc2c1ncn2C[C@H]1COP(=O)(O)CO1
# 1        CHEMBL113930                Nc1ncnc2c1ncn2C[C@@H](CO)OP(=O)(O)O
# 2        CHEMBL494759                          Nc1ncnc2c1ncn2C[C@H](O)CO
# 3        CHEMBL114867                Nc1ncnc2c1ncn2C[C@@H]1COP(=O)(O)CO1
# 4        CHEMBL321500                         Nc1ncnc2c1ncn2C[C@@H](O)CO
# 5        CHEMBL326139                 Nc1ncnc2c1ncn2C[C@H](CO)OP(=O)(O)O
# 6          CHEMBL1643   NC(=O)c1ncn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)n1
# 7        CHEMBL392630                Nc1ccn(C[C@H]2COP(=O)(O)CO2)c(=O)n1
# 8           CHEMBL152              Nc1ccn(C[C@@H](CO)OCP(=O)(O)O)c(=O)n1
# 9       CHEMBL3290663  Nc1ncc(F)c2c1ncn2[C@@H]1C[C@H](O)[C@@H](O)[C@H]1O
# 10      CHEMBL3357216  Nc1ncc(F)c2c1ncn2[C@@H]1C[C@H](CCO)[C@@H](O)[C...
# 11      CHEMBL3357215  Nc1ncc(F)c2c1ncn2[C@@H]1C[C@H](CO)[C@@H](O)[C@...
#
# ...

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 20
# -rw-r--r-- 1 root root 6320 May 24 06:21 bioactivity_data.csv
# -rw-r--r-- 1 root root  892 May 24 06:37 bioactivity_preprocessed_data.csv
# drwx------ 6 root root 4096 May 24 06:22 gdrive
# drwxr-xr-x 1 root root 4096 May 17 13:39 sample_data

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'
